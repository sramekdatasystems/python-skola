# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/Dice_roll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dice roll
import random
# assigning a variable to a random number between 1 and 6
dice_roll = int(random.randint(1, 6))

# result listing by users
print(f"Kostkou jsi hodil: {dice_roll}")
# Out:
# Kostkou jsi hodil: 2
