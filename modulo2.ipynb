# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/modulo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#modulo2
number = int(input("Zadejte první číslo:\n"))

if number % 2 == 0:
    print(f"Číslo {number} je sudé")
else:
    print(f"Číslo {number} je liché")
# Out:
# Zadejte počet minut:
# 125
# zaný počet minut 125 je 2 h a 5 m
