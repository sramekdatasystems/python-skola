# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/check%20whether%20the%20entered%20year%20is%20a%20leap%20year2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check whether the entered year is a leap year
year = int(input("Zadejte rok:\n"))

#checking divisibility by four and hunderds and four hundred
if (year % 4 == 0 and year % 100 > 0) or (year % 4 == 0 and year % 100 == 0 and year % 400 == 0):
    print(f"Rok {year} je přestupný")
else:
    print(f"Rok {year} není přestupný")
# Out:
# Zadejte rok:
# 2002
# Rok 2002 není přestupný
