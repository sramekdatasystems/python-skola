# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/loop_for_printing_names.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# loop_for_printing_names

# creation of a sheet
list_winners = ["Petr", "Jana", "Karel", "Eva"]

# loop for printing names
for individual_name in list_winners:
    print(f"Blahopřejeme, {individual_name}")
# Out:
# Blahopřejeme, Petr
# Blahopřejeme, Jana
# Blahopřejeme, Karel
# Blahopřejeme, Eva
