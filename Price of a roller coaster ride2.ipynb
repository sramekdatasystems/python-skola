# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/Price%20of%20a%20roller%20coaster%20ride2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Price of a roller coaster ride
print("Vítejte na horské dráze")
height = int(input("Jaká je Vaše výška v cm?\n"))

#the condition tests the height
if height >= 87:
    print("Můžete jet na horské dráze")
    age = int(input("Zadejte svůj věk:\n"))

    #condition tests age
    if age < 12:
        bill = 50
    elif age < 18:
        bill = 100
    elif 40 <= age <= 50:
        bill = 0
    else:
        bill = 150
    photo = input("Chcete se nechat vyfotit? Ano/Ne\n").lower()

    #testing if he wants a photo
    if photo == "ano":
        print(f"Cena Vaší vstupenky je {bill + 50} Kč")
    else:
        print(f"Cena Vaší vstupenky je {bill} Kč")


else:
    print("Omlouváme se, ale na horské dráze jet nemůžete")
# Out:
# Vítejte na horské dráze
# Jaká je Vaše výška v cm?
# 150
# Můžete jet na horské dráze
# Zadejte svůj věk:
# 40
# Chcete se nechat vyfotit? Ano/Ne
# ano
# Cena Vaší vstupenky je 50 Kč
