# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/field_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set_1 = ["🟧", "🟧", "🟧"]
set_2 = ["🟧", "🟧", "🟧"]
set_3 = ["🟧", "🟧", "🟧"]

all_sets = [set_1, set_2, set_3]

print(f"{set_1}\n {set_2}\n {set_3}")

position = input("Zadejte souřeadnice: ")

num_1 = int(position[0])
num_2 = int(position[1])

print(f"{num_1} a {num_2}")

all_sets[num_1-1][num_2-1] = " X"

print(" ".join(set_1))
print(" ".join(set_2))
print(" ".join(set_3))
# Out:
# ['🟧', '🟧', '🟧']
#  ['🟧', '🟧', '🟧']
#  ['🟧', '🟧', '🟧']
# Zadejte souřeadnice: 22
# 2 a 2
# 🟧 🟧 🟧
# 🟧  X 🟧
# 🟧 🟧 🟧
