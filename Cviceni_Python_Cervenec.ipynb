# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/Cviceni_Python_Cervenec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("zadejte své jméno: ")
age = input("Zadejte svuj vek: ")
print (f"Jmenuji se {name} a je mi {age} let")
# Out:
# zadejte své jméno: Zbyněk
# Zadejte svuj vek: 44
# Jmenuji se Zbyněk a je mi 44 let
