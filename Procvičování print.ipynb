# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/Procvi%C4%8Dov%C3%A1n%C3%AD%20print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Naučili jsme se mnoho věcí o stringu")
print('Spojení stringu děláme pomocí znaménka "+"')
print("Také jsme používali print('Nějaký text')")
print("První řádek\nDruhý řádek se dělá pomocí lomítka a n")
