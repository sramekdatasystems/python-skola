# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/cycle_of_squares_of_numbers_from_1_to_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# cycle_of_squares_of_numbers_from_1_to_6

for number in range(1, 7):
    print(f"Druhá mocnina {number} je {number ** 2}")
# Out:
# Druhá mocnina 1 je 1
# Druhá mocnina 2 je 4
# Druhá mocnina 3 je 9
# Druhá mocnina 4 je 16
# Druhá mocnina 5 je 25
