# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/modulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#modulo
dividend = int(input("Zadejte první číslo:\n"))
divisor = int(input("Zadejte druhé číslo:\n"))

modulo = dividend % divisor
print(f"Zbytek po dělení je {modulo}")
# Out:
# Zadejte první číslo:
# 10
# Zadejte druhé číslo:
# 3
# Zbytek po dělení je 1
