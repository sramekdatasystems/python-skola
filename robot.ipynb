# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/robot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from robot_class import Robot

robot_1 = Robot("Modrásek", "Modrý", 40)
robot_1.introduce_self()

robot_2 = Robot("Zlutasek", "Zlutý", 50)
robot_2.introduce_self()
# Out:
# My name is Modrásek
# My color is Modrý
# My weight is 40
# My name is Zlutasek
# My color is Zlutý
# My weight is 50
