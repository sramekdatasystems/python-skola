# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/P%C5%99eveden%C3%AD%20zadan%C3%A9ho%20textu%20do%20listu%20a%20na%20%C4%8D%C3%ADsla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to display the lowest set temperature

temperatures_list = input("zadejte teploty oddělené mezerou: ").split(", ")
print(temperatures_list)
temperatures_list_number = []

for index in range(0, len(temperatures_list)):
    temperatures_list_number.append(int(temperatures_list[index]))

print(temperatures_list_number)
