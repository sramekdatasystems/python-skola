# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/coin%20tossing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#coin tossing
import random
coin = random.randint(0,1)

#assigning a random value to a coin side
if coin == 0:
    print("Hodil jsi Pannu")
else:
    print("Hodil jsi Orla")
