# %% [markdown]
# <a href="https://colab.research.google.com/github/sramekdatasystems/python-skola/blob/main/Procvi%C4%8Dov%C3%A1n%C3%AD%20print3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
firstname = input("Vaše křestní jméno: ")
surname = input("Vaše příjmení: ")

print(f"Vaše celé jméno je {firstname} {surname}")
